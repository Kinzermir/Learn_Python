# %%
print("logic 1")
print("logic 2")

l1 : list[int] = [1,2,3,4,5]

try :
    print(l1[10])
    print(xyz)
    print(10/0)

except IndexError:     # short form of exception 
    print("error : IndexError ")
except NameError:
    print("error : NameError ")
except ZeroDivisionError:
    print("error : ZeroDivisionError ")

print("logic 3")
print("logic 4")

# above we see multiple error dynamically and we displayed message particularly for individual class.
# Out:
# logic 1
# logic 2
# error : IndexError
# logic 3
# logic 4

# %%
print("logic 1")
print("logic 2")
xyz = "hello"
l1 : list[int] = [1,2,3,4,5]

try :
    print(l1[1])
    print(xyz)
    print(10/2)
    open("abc.txt") # it means i upload the file but the file doesn't support

except IndexError:     # short form of exception 
    print("error : IndexError ")
except NameError:
    print("error : NameError ")
except ZeroDivisionError:
    print("error : ZeroDivisionError ")
except :
    print("Something is wrong")

print("logic 3")
print("logic 4")

# above we see multiple error dynamically and we displayed message particularly for individual class.
# Out:
# logic 1
# logic 2
# 2
# hello
# 5.0
# Something is wrong
# logic 3
# logic 4

# %%
try :
    print(age)
    print(l1[200])
except Exception as e:   # error e me a jae ga 
    print(f"Something is wrong! \n{e}")
# Out:
# Something is wrong!
# name 'age' is not defined

# %%
try :
    print(l1[299])
except Exception as e:   # error e me a jae ga
    print(f"Variable is not defined! \n{e}")
# Out:
# Variable is not defined!
# list index out of range

# %%
class StudentCard():
    def __init__(self, roll_no: int, name: str, age:int):
        if age < 18 or age > 60:
            raise StudentsAgeError("You arn't eligble for the program")
        self.roll_no = roll_no
        self.name = name
        self.age = age

class StudentsAgeError(Exception): # custom error class
    pass
student1 = StudentCard(1, "Qasim", 40)
print(student1.name, student1.roll_no, student1.age)

# If the age is outside the allowed range, it will raise and print the custom error message:
# Out:
# Qasim 1 40

# %%
student1 = StudentCard(1, "Qasim", 70)
print(student1.name, student1.roll_no, student1.roll_no)
# StudentsAgeError  this error we have generated
# Out:
# ---------------------------------------------------------------------------
# StudentsAgeError                          Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 student1 = StudentCard(1, "Qasim", 70)
#       2 print(student1.name, student1.roll_no, student1.roll_no)
#
# Cell In[17], line 4, in StudentCard.__init__(self, roll_no, name, age)
#       2 def __init__(self, roll_no: int, name: str, age:int):
#       3     if age < 18 or age > 60:
# ----> 4         raise StudentsAgeError("You arn't eligble for the program")
#       5     self.roll_no = roll_no
#       6     self.name = name
#
# StudentsAgeError: You arn't eligble for the program

# %% [markdown]
# # File handling
# https://www.w3schools.com/python/python_file_handling.asp
# <img src = "https://th.bing.com/th/id/OIP.XkqOKPSX4qsw3OBvQQsjcAHaC-?rs=1&pid=ImgDetMain">

# %%
from typing import TextIO
data : TextIO = open("./abc.txt") # open :- make connection with file 
print(data.read()) # read is method
data.close() # close the connection
# it will read all the lines mentioned in abc.txt file
# Out:
# line 1
# line 2

# %%
with open("./abc.txt") as file:
    print( type(file))
    print(file.read())
    
print("Pakistan zindabad")
# with use krne se file automatically close ho jate hai
# Out:
# <class '_io.TextIOWrapper'>
# line 1
# line 2
# Pakistan zindabad

# %%
with open("./abc.txt") as file:
    print( type(file))
    print(file.readline()) # it will read only first line 
    print(file.readline())
    
print("Pakistan zindabad")
# Out:
# <class '_io.TextIOWrapper'>
# line 1
#
# line 2
#
# Pakistan zindabad

# %%
with open("./abc.txt") as file:
    print( type(file))
    print(file.readlines()) # it will read only first lines in the form of iteration
# Out:
# <class '_io.TextIOWrapper'>
# ['line 1\n', 'line 2\n', 'line 3\n']

# %%
with open("./abc.txt") as file:
    print( type(file))
    print(file.readlines()[:3]) # slicing
# Out:
# <class '_io.TextIOWrapper'>
# ['line 1\n', 'line 2\n', 'line 3\n']

# %%
with open("./abc.txt", 'r') as file: # file is ka nick name ho gya 
    print( type(file))
    file.write("Pakistan zindabad") # not writable
# Out:
# <class '_io.TextIOWrapper'>
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[28], line 3
#       1 with open("./abc.txt", 'r') as file: # file is ka nick name ho gya
#       2     print( type(file))
# ----> 3     file.write("Pakistan zindabad")
#
# UnsupportedOperation: not writable

# %%
with open("./abc.txt", 'w') as file: # file is ka nick name ho gya 
    print( type(file))
    file.write("Pakistan zindabad") # not 

# not readable cuz we applied method of w
# Out:
# <class '_io.TextIOWrapper'>

# %%
with open("./abc.txt", 'w') as file: # file is ka nick name ho gya 
    file.write("Pakistan zindabad")  # it will remove all the text and update with the current content 
# now you can go to abc.txt file and check teh content, you have written paksitan zindabad

# %%
with open("./abc.txt", 'w') as file: # file is ka nick name ho gya 
    file.write("Pakistan zindabad")

# %%
with open("./abc.txt", 'r+') as file:
    print(file.read())
    file.write("hello world")  # first it read and then it write 
    print("after", file.read())
# Out:
# hello world
# after

# %%
with open("./abc.txt", 'r+') as file:
    print(file.read())
    file.write("hello world")  # first it read and then it write 
    file.seek(0) # here cursour becomes to zero postion and display all the line
    print("after", file.read())
# Out:
# hello worldhello worldhello world
# after hello worldhello worldhello worldhello world

# %% [markdown]
# ## Change mode

# %%
with open("input.txt", "r") as file:
    print(file.read())
# FileNotFoundError
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 with open("input.txt", "r") as file:
#       2     print(file.read())
#
# File c:\Users\Dell1\anaconda3\envs\python12\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input.txt'

# %%
with open("input.txt", "w") as file:
    file.write("Hello, World!")

# it means input.txt file has beem made due to w mode agr file nahe tu bana do

# %%
with open("abc2.txt", "a") as file: # this is append mode 
    file.write("pakistan") # it will reomve all the conent in file and update with current file

# %%
with open("input2.txt", "a") as file: # this is append mode if file isn't present then create file.
    file.write("zindabad") # it will reomve all the conent in file and update with current file

# first i write pakistan it has been added then i wrote zindabad id add the zindabad

# %%
with open("input3.txt", "x") as file: 
    file.write("pakistan")

# if file not exist then it will create the file 
# iska kaam sirf file create krna hai oor agr file already mojod hai tu it will throw error

# %%
# if file is present it will throw error
with open("input3.txt", "x") as file: 
    file.write("pakistan")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[75], line 2
#       1 # if file is present it will throw error
# ----> 2 with open("input3.txt", "x") as file:
#       3     file.write("pakistan")
#
# File c:\Users\Dell1\anaconda3\envs\python12\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'input3.txt'

# %%
with open("input3.txt", 'rb+') as file:  # read binary mode
    print(file.read())
# it will only read in binary modee
# Out:
# b'pakistan'

# %% [markdown]
# https://stackoverflow.com/questions/6648493/how-to-open-a-file-for-both-reading-and-writing
# * then go to it's view page resource then copy table
# * then select markdown
#
# <div class="s-table-container">
#     <table class="s-table">
#     <thead>
#     <tr>
#     <th style="text-align: center;">Mode</th>
#     <th style="text-align: center;">r</th>
#     <th style="text-align: center;">r+</th>
#     <th style="text-align: center;">w</th>
#     <th style="text-align: center;">w+</th>
#     <th style="text-align: center;">a</th>
#     <th style="text-align: center;">a+</th>
#     </tr>
#     </thead>
#     <tbody>
#     <tr>
#     <td style="text-align: center;">Read</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;">+</td>
#     </tr>
#     <tr>
#     <td style="text-align: center;">Write</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     </tr>
#     <tr>
#     <td style="text-align: center;">Create</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     </tr>
#     <tr>
#     <td style="text-align: center;">Cover</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;"></td>
#     </tr>
#     <tr>
#     <td style="text-align: center;">Point in the beginning</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;"></td>
#     </tr>
#     <tr>
#     <td style="text-align: center;">Point in the end</td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;"></td>
#     <td style="text-align: center;">+</td>
#     <td style="text-align: center;">+</td>
#     </tr>
#     </tbody>
#     </table>

# %% [markdown]
# ## read some real world data file
# * image
# * csv
# * live camera

# %%
import pandas as pd
df : pd.DataFrame = pd.read_csv('data.csv')
df
# Out:
#    id               name  education
# 0   1          "Sir Zia"    "Master"
# 1   2        "Sir Osama"    "Master"
# 2   3   "Muhammad Qasim"      "MBBS"

# %%
import pandas as pd
df : pd.DataFrame = pd.read_excel('./Book1.xlsx')
df
# Out:
#    S.No    name
# 0     1  martin
# 1     2   hanry
# 2     3   qasim
# 3     4   peter

# %%
# install this panda dependency to access the excel file 
# !pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/250.9 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/250.9 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/250.9 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/250.9 kB ? eta -:--:--
#    ------ --------------------------------- 41.0/250.9 kB ? eta -:--:--
#    ----------- --------------------------- 71.7/250.9 kB 218.6 kB/s eta 0:00:01
#    ----------- --------------------------- 71.7/250.9 kB 218.6 kB/s eta 0:00:01
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.9 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.9 kB 435.7 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/165.9 kB 435.7 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/165.9 kB 245.8 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/165.9 kB 381.3 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/165.9 kB 504.4 kB/s eta 0:00:01
#      ------------------------------- ---- 143.4/165.9 kB 473.7 kB/s eta 0:00:01
#      ------------------------------------ 165.9/165.9 kB 474.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 

img = mpimg.imread('image.webp')
plt.imshow(img)

# %%
# !pip install PyPDF2
# Out:
# ...
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/232.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/232.6 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/232.6 kB 262.6 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/232.6 kB 245.8 kB/s eta 0:00:01
#    ------------- ------------------------- 81.9/232.6 kB 383.3 kB/s eta 0:00:01
#    ------------------ ------------------- 112.6/232.6 kB 469.7 kB/s eta 0:00:01
#    -------------------------- ----------- 163.8/232.6 kB 546.6 kB/s eta 0:00:01
#    --------------------------------- ---- 204.8/232.6 kB 593.2 kB/s eta 0:00:01
#    -------------------------------------- 232.6/232.6 kB 619.3 kB/s eta 0:00:00
# ...

# %%
from typing import List
import PyPDF2

def read_pdf(file_path: str) -> List[str]:
    with open(file_path, 'rb') as file:  # The 'b' in 'rb' stands for binary mode
        reader: PyPDF2.PdfReader = PyPDF2.PdfReader(file)
        text_content: List[str] = [page.extract_text() for page in reader.pages]
        return text_content

pages: list[str] = read_pdf("./Slide 3.pdf")
pages
# Out:
# ['Overview of Economic Theories and \nPolicies\nThis document provides a comprehensive examination of various economic theories and policies \ncrucial for understanding the complex mechanisms behind income and employment determination, \nas well as fiscal and monetary dynamics. Diving into the classical, modern (Keynesian), and post \nKeynesian approaches, the document discusses the nuances of each and how they contrast with \neach other. Additionally, it delves into the multiplier and accelerator concept, inflation, business \ncycles, international trade, protectionism, and balance of payments. For students of economics, \nthis exploration offers detailed insights, formulas, and examples to foster a deeper understanding \nof the subject matter.\nby Kinzer Mir KA\n',
# ...
